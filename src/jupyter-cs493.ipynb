# %% [markdown]
# Usage: run `make install` and run this notebook in Appmode. That should make a remotely-accessible flight GUI

# %%
# %run flight.py --flight-gui
